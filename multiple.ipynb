# %%
#multiple linear regression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression   
from sklearn.model_selection import train_test_split

df = pd.read_csv('student_habits_performance.csv')
df.head()
x = df[['study_hours_per_day', 'sleep_hours', 'social_media_hours']]
y = df['age']
df.isnull()
df.dropna(inplace=True)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
model= LinearRegression()
model.fit(x_train, y_train)
print(model.score(x_test, y_test))
y_pred = model.predict(x_test)
print(y_pred)
plt.scatter(x_test['study_hours_per_day'], y_test, color='blue', label='Actual')
plt.scatter(x_test['study_hours_per_day'], y_pred, color='red', label='Predicted', linewidths=2)
plt.title('Multiple Linear Regression')
plt.xlabel('Study Hours per Day')
plt.ylabel('Age')
plt.legend()
plt.show()
# Out:
# -0.009170769810690205
# [20.62634401 20.72187817 20.45683248 20.3259357  20.53828141 20.47579848
#  20.19904106 20.41989223 20.5383038  20.41026777 20.23426193 20.65193934
#  20.658922   20.70526994 20.75809706 20.4859869  20.51309938 20.30642979
#  20.62370895 20.38074539 20.43096045 20.47140659 20.53848415 20.30391404
#  20.41280481 20.55523464 20.25262704 20.40847338 20.38198365 20.58263948
#  20.59630411 20.32959283 20.70418851 20.56072367 20.49755695 20.50913482
#  20.40394594 20.62099834 20.62672705 20.60420252 20.81140472 20.77688219
#  20.35600582 20.48198535 20.69393232 20.37765952 20.33256554 20.42459271
#  20.38570855 20.54747125 20.61047953 20.65856192 20.60722114 20.6961025
#  20.48506339 20.55296028 20.54038382 20.49444865 20.45362673 20.62299547
#  20.74669224 20.59202422 20.72225343 20.44995504 20.54588689 20.69071931
#  20.33433756 20.41950972 20.54997129 20.4922264  20.47193137 20.48074651
#  20.34792711 20.48040881 20.30227814 20.45131429 20.5601222  20.38726995
#  20.53052475 20.55843252 20.61243127 20.50565022 20.54269626 20.42425444
#  20.57296129 20.50459225 20.3871725  20.35465497 20.35941483 20.63291448
#  20.47898181 20.37369496 20.42770153 20.54792153 20.3230604  20.36898774
#  20.77580133 20.34402358 20.48555901 20.5845319  20.21677496 20.5261855
#  20.41653696 20.51113194 20.61518726 20.44131352 20.63292904 20.59591377
#  20.2919245  20.55066296 20.4128877  20.12852423 20.16105688 20.83646018
#  20.40897578 20.35962595 20.49680591 20.38256274 20.37344741 20.59318855
#  20.60872208 20.48114415 20.39600168 20.38109096 20.50146157 20.45486556
#  20.65895899 20.53874682 20.29210428 20.69455565 20.35351359 20.41845849
#  20.59678465 20.49647603 20.41587612 20.39148155 20.67378065 20.42236317
#  20.59583087 20.4875108  20.41960774 20.39995842 20.43284447 20.50797831
#  20.50604895 20.20293786 20.4892755  20.45075872 20.51314311 20.36864217
#  20.27973843 20.77142399 20.36205824 20.46506181 20.35244672 20.61177826
#  20.67007985 20.4834796  20.36092416 20.72950659 20.50724188 20.53339333
#  20.43966865 20.61964693 20.38160171 20.60068875 20.70010405 20.31646864
#  20.50362392 20.5409915  20.54846253 20.43551757 20.43843821 20.34442122
#  20.49565727 20.47721767 20.60741604 20.52281457 20.56735242 20.44286093
#  20.47997309 20.67061976 20.30427527 20.51623007 20.56192499 20.33052308
#  20.66536372 20.68716021 20.54743373 20.40533487 20.53644111 20.54679528
#  20.44965543 20.57323852 20.38302032 20.43186101 20.57181991 20.69160532
#  20.49390091 20.5150517 ]
