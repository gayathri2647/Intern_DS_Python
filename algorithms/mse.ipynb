# %%
#multiple linear regression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression   
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

df = pd.read_csv('student_habits_performance.csv')
df.head()
x = df[['study_hours_per_day', 'sleep_hours', 'social_media_hours']]
y = df['age']
df.isnull()
df.dropna(inplace=True)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
model= LinearRegression()
model.fit(x_train, y_train)
print(model.score(x_test, y_test))
y_pred = model.predict(x_test)
print(y_pred)
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', mse)
plt.scatter(x_test['study_hours_per_day'], y_test, color='blue', label='Actual')
plt.scatter(x_test['study_hours_per_day'], y_pred, color='red', label='Predicted', linewidths=2)
plt.title('Multiple Linear Regression')
plt.xlabel('Study Hours per Day')
plt.ylabel('Age')
plt.legend()
plt.show()
# Out:
# -0.008081837577479156
# [20.63802573 20.70760268 20.56744525 20.53727167 20.58824797 20.46595853
#  20.41682666 20.47824303 20.48479834 20.5353197  20.613811   20.46289779
#  20.71172275 20.48141393 20.49467665 20.34418669 20.51840052 20.58732594
#  20.42783713 20.65277788 20.24183192 20.60744242 20.3703013  20.4640062
#  20.59735663 20.54665648 20.5323642  20.42146699 20.46392543 20.49098813
#  20.53865322 20.57197769 20.6733018  20.62593553 20.44416058 20.44763067
#  20.71706862 20.54385566 20.72720757 20.47466805 20.45186092 20.69351108
#  20.36403796 20.62623244 20.40216128 20.54665612 20.65538139 20.6536452
#  20.5460023  20.65310648 20.44320913 20.53108717 20.40663563 20.51539259
#  20.3625161  20.73664145 20.52135073 20.46064892 20.51685527 20.7195646
#  20.41368708 20.54312492 20.58645634 20.65229461 20.62105375 20.71034576
#  20.35325048 20.66208085 20.47493855 20.72167653 20.56297656 20.48995856
#  20.33429521 20.57791243 20.71380828 20.49754536 20.78553187 20.62485317
# ...
